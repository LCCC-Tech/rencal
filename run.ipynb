# %%
from weather.core.data_downloader import DownloadManager

# %%
dm = DownloadManager()

# %%
dm.download_era5
# Out:
# <bound method DownloadManager.download_era5 of <weather.core.data_downloader.DownloadManager object at 0x315fd7020>>

# %%
from weather.calibration.wind.wind_calibrator import WindCalibrator
# Out:
# <bound method DownloadManager.download_all of <weather.core.data_downloader.DownloadManager object at 0x315fd7020>>

# %%
calibrator = WindCalibrator(visual_output=True)

print(calibrator)
# Out:
# [INFO] - Plant data loaded: 10 plants, 1634.2 MW total capacity - [data_loader] - 2026-05-11 13:59:05
# [INFO] - Generation data loaded: 26040 records, 35 plants - [data_loader] - 2026-05-11 13:59:05
# [WARNING] - Failed to load /Users/matthewcampbell/Weather Repo/weather/data/era5/era5_data.nc: found the following matches with the input file in xarray's IO backends: ['netcdf4', 'h5netcdf']. But their dependencies may not be installed, see:
# https://docs.xarray.dev/en/stable/user-guide/io.html
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html - [data_loader] - 2026-05-11 13:59:06
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# ...
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# /Users/matthewcampbell/Weather Repo/weather/weather/core/data_loader.py:308: UserWarning: rename 'time' to 'time' does not create an index anymore. Try using swap_dims instead or use set_index after rename to create an indexed coordinate.
#   ds = ds.rename({time_dim: "time"})
# [INFO] - ERA5 data loaded: 556 files, 405408 time periods - [data_loader] - 2026-05-11 14:00:11
# <weather.calibration.wind.wind_calibrator.WindCalibrator object at 0x3136cc1a0>
